# %%
from tkinter import ttk
import tkinter as tk
from tkinter import *
from tkinter.ttk import *
import operator
import csv
import pyodbc as pc    
import matplotlib.pyplot as plt
import pandas as pd
import mysql.connector as mysql
global tree
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from tkinter import Toplevel, Label
m = tk.Tk()
m.geometry("400x300")
m.title('Emission Project')

def graph():
    b=Toplevel(m)
    b.geometry("1200x900")
    b.title("Bar graph")
    ttk.tkinter.Button(b,text="A",command=a).pack()
    ttk.tkinter.Button(b,text="B",command=b1).pack()
    ttk.tkinter.Button(b,text="C",command=c1).pack()
    ttk.tkinter.Button(b,text="D",command=d1).pack()
    ttk.tkinter.Button(b,text="E",command=e1).pack()
    ttk.tkinter.Button(b,text="F",command=f1).pack()
    ttk.tkinter.Button(b,text="G",command=g1).pack()
    ttk.tkinter.Button(b,text="H",command=h1).pack()
    ttk.tkinter.Button(b,text="I",command=i1).pack()
    ttk.tkinter.Button(b,text="J",command=j1).pack()
    ttk.tkinter.Button(b,text="K",command=k1).pack()
    ttk.tkinter.Button(b,text="L",command=l1).pack()
    ttk.tkinter.Button(b,text="M",command=m1).pack()
    ttk.tkinter.Button(b,text="N",command=n1).pack()
    ttk.tkinter.Button(b,text="O",command=o1).pack()
    ttk.tkinter.Button(b,text="P",command=p1).pack()
    ttk.tkinter.Button(b,text="Q",command=q1).pack()
    ttk.tkinter.Button(b,text="R",command=r1).pack()
    ttk.tkinter.Button(b,text="S",command=s1).pack()
    ttk.tkinter.Button(b,text="T",command=t1).pack()
    ttk.tkinter.Button(b,text="U",command=u1).pack()
    ttk.tkinter.Button(b,text="V",command=v1).pack()
    ttk.tkinter.Button(b,text="Y",command=y1).pack()
    ttk.tkinter.Button(b,text="Z",command=z1).pack()
    

    

#now analysis

def intro1():
    w=Toplevel(m)
    w.geometry("400x300")
    w.title("BRIEF SUMMARY")
    summary_label = Label(w, text=
                        
    """
    This datasets depicts the CO2 emission based on different countries starting from 1990-2018 .
    Also I have used python libraries to visualize the data much clearly and efficiently .
    Using the MySql as background have extracted the data with using various options like sorting
    based on alphabetical way
   
    """, wraplength=380, justify=tk.LEFT, padx=10, pady=10)
    summary_label.pack(fill=tk.BOTH, expand=True)

    
    
def new():
    w4=Toplevel(m)
    w4.geometry("1200x900")
    w4.title('csv')
  
    
    
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions")
       

    tree = ttk.Treeview(w4, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()

def analysis():
    w1=Toplevel(m)
    w1.geometry("400x300")
    w1.title("A better lookout")
    ttk.tkinter.Button(w1,text="SORTING",command=sort1).pack()
    ttk.tkinter.Button(w1,text="GRAPH",command=graph).pack()
    ttk.tkinter.Button(w1,text="COMPARISION",command=map1).pack()
def sort1():
      
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    ttk.tkinter.Button(w3,text="SORTING based on 1990",command=sort1990).pack()
    ttk.tkinter.Button(w3,text="SORTING based on 1995",command=sort1995).pack()
    ttk.tkinter.Button(w3,text="SORTING based on 2000",command=sort2000).pack()
    ttk.tkinter.Button(w3,text="SORTING based on 2005",command=sort2005).pack()
    ttk.tkinter.Button(w3,text="SORTING based on 2010",command=sort2010).pack()
    ttk.tkinter.Button(w3,text="SORTING based on 2013",command=sort2013).pack()
    ttk.tkinter.Button(w3,text="SORTING based on 2018",command=sort2018).pack()
def map1():
    w6=Toplevel(m)
    w6.geometry("1200x900")
    w6.title('map')
    ttk.tkinter.Button(w6,text="map based on 1990",command=map1990).pack()
    ttk.tkinter.Button(w6,text="map based on 1995",command=map1995).pack()
    ttk.tkinter.Button(w6,text="map based on 2000",command=map2000).pack()
    ttk.tkinter.Button(w6,text="map based on 2005",command=map2005).pack()
    ttk.tkinter.Button(w6,text="map based on 2010",command=map2010).pack()
    ttk.tkinter.Button(w6,text="map based on 2013",command=map2013).pack()
    ttk.tkinter.Button(w6,text="map based on 2018",command=map2018).pack()
    
    
def sort1990():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (1990)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()
def sort1995():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (1995)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()
def sort2000():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (2000)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()
def sort2005():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (2005)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()
def sort2010():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (2010)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()
def sort2013():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (2013)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()
def sort2018():
    w3=Toplevel(m)
    w3.geometry("1200x900")
    w3.title('sorted')
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM production_based_co2_emissions ORDER BY `Metric tons of CO2e per capita (2018)` ")
       

    tree = ttk.Treeview(w3, column=("c1", "c2", "c3","c4","c5","c6","c7","c8","c9","c10","c11"), show='headings')
    tree.column("#1", anchor=tk.CENTER)
    tree.heading("#1", text="ISO3")
    tree.column("#2", anchor=tk.CENTER)
    tree.heading("#2", text="Country")
    tree.column("#3", anchor=tk.CENTER)
    tree.heading("#3", text="Continent")
    tree.column("#4", anchor=tk.CENTER)
    tree.heading("#4", text="Hemisphere")
    tree.column("#5", anchor=tk.CENTER)
    tree.heading("#5", text="Metric tons of CO2e per capita (1990)")
    tree.column("#6", anchor=tk.CENTER)
    tree.heading("#6", text="Metric tons of CO2e per capita (1995)")
    tree.column("#7", anchor=tk.CENTER)
    tree.heading("#7", text="Metric tons of CO2e per capita (2000)")
    tree.column("#8", anchor=tk.CENTER)
    tree.heading("#8", text="Metric tons of CO2e per capita (2005)")
    tree.column("#9", anchor=tk.CENTER)
    tree.heading("#9", text="Metric tons of CO2e per capita (2010)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2013)")
    tree.column("#10", anchor=tk.CENTER)
    tree.heading("#10", text="Metric tons of CO2e per capita (2018)")
    
    
    tree.pack()
 
    rows = cursor.fetchall()   
    for row in rows:
        tree.insert("", tk.END, values=row)   
    cursor = conn.cursor()
    conn.commit()
    cursor.close()

ttk.tkinter.Button(m,text="CSV",command=new).pack()
ttk.tkinter.Button(m,text="INTRODUCTION ",command=intro1).pack()
ttk.tkinter.Button(m,text="ANALYSIS",command=analysis).pack()


def dbconnection():
    data = pd.read_csv (r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv")   
    df = pd.DataFrame(data)
    conn = mysql.connect(user='root', password='zidan', host='localhost', database='co')
    cursor = conn.cursor()
    print("executed")
    cursor.execute("SELECT * FROM production_based_co2_emissions")
    row = cursor.fetchone()
    while row is not None:
        print(row)
        row = cursor.fetchone()
        cursor = conn.cursor()
        conn.commit()
        cursor.close()

def matplot():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Afghanistan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()

    
    
def matplot2():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Albania"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()

def matplot3():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Algeria"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot4():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Angola"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot5():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Antigua and Barbuda"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot6():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Argentina"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot7():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Armenia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot8():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Australia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot9():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Austria"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot10():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Azerbaijan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot11():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bahamas"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot12():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bahrain"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot13():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bangladesh"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot14():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Barbados"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot15():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Belarus"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot16():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Belgium"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot17():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Belize"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot18():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Benin"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot19():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bhutan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot20():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bolivia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot21():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bosnia and Herzegovina"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot22():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Botswana"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot23():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Brazil"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot24():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Brunei"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot25():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Bulgaria"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot26():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Burkina Faso"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot27():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Burundi"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot28():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Cambodia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot29():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Cameroon"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot30():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Canada"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot31():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Cape Verde"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot32():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Central African Republic"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot33():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Chad"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot34():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Chile"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot35():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "China"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot36():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Colombia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot37():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Comoros"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot38():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Costa Rica"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot39():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Croatia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot40():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Cuba"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot41():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Cyprus"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot42():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Czech Republica"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot43():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Denmark"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot44():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Djibouti"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot45():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Dominica"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot46():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Dominican Republic"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot47():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Ecuador"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot48():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Egypt"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot49():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "El Salvador"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot50():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Equatorial Guinea"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot51():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Eritrea"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot52():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Estonia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot53():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Eswatini"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot54():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Ethiopia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot55():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Fiji"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot56():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Finland"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot57():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "France"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot58():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Gabon"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot59():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Gambia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot60():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Georgia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot61():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Germany"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot62():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Ghana"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot63():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Greece"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot64():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Grenada"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot65():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Guatemala"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot66():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Guinea"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot67():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Guinea-Bissau"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot68():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Guyana"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot69():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Haiti"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot70():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Honduras"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot71():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Hungary"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot72():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Iceland"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot73():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "India"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot74():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Indonesia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot75():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Iran"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot76():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Iraq"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot77():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Ireland"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot78():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Israel"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot79():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Italy"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot80():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Ivory Coast"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot81():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Jamaica"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot82():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Japan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot83():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Jordan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot84():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Kazakhstan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot85():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Kenya"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot86():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Kiribati"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot87():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Kuwait"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot88():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Kyrgyzstan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot89():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Laos"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot90():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Latvia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot91():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Lebanon"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot92():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Lesotho"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot93():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Liberia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot94():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Libya"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot95():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Lithuania"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot96():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Luxembourg"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot97():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Madagascar"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot98():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Malawi"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot99():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Malaysia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot100():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Maldives"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot101():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Mali"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot102():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Malta"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot103():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Mauritania"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot104():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Mauritius"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot105():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Mexico"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot106():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Moldova"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot107():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Mongolia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot108():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Montenegro"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot109():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Morocco"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot110():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Mozambique"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot111():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Myanmar"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot112():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Namibia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot113():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Nauru"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot114():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Nepal"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot115():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Netherlands"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot116():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "New Zealand"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot117():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Nicaragua"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot118():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Niger"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot119():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Nigeria"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot120():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "North Korea"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot121():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Norway"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot122():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Oman"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot123():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Pakistan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot124():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Palau"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot125():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Panama"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot126():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Papua New Guinea"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot127():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Paraguay"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot128():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Peru"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot129():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Philippines"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot130():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Poland"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot131():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Portugal"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot132():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Qatar"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot133():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Republic of the Congo"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot134():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Romania"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot135():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Russia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot136():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Rwanda"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot137():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Saint Kitts and Nevis"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot138():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Saint Lucia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot139():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Saint Vincent and the Grenadines"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot140():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Samoa"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot141():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "São Tomé and Príncipe"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot142():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Saudi Arabia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot143():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Senegal"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot144():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Serbia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot145():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Seychelles"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot146():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Sierra Leone"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot147():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Singapore"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot148():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Slovakia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot149():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Slovenia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot150():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Solomon Islands"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot151():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "South Africa"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot152():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "South Korea"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot153():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Spain"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot154():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Sri Lanka"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot155():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Sudan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot156():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Suriname"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot157():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Sweden"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot158():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Switzerland"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot159():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Syria"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot160():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Tajikistan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot161():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Tanzania"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot162():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Thailand"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot163():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Togo"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot164():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Tonga"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot165():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Trinidad and Tobago"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot166():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Tunisia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot167():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Turkey"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot168():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Turkmenistan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot169():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Uganda"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot170():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Ukraine"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot171():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "United Arab Emirates"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot172():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "United Kingdom"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot173():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "United States"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot174():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Uruguay"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot175():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Uzbekistan"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot176():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Vanuatu"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot177():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Venezuela"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot178():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Vietnam"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot179():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Yemen"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()
def matplot180():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Zambia"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()

def matplot181():
    plt.rcParams["figure.figsize"] = [10, 6]
    plt.rcParams["figure.autolayout"] = True
    columns = ["Country",
           "Metric tons of CO2e per capita (1990)",
           "Metric tons of CO2e per capita (1995)",
           "Metric tons of CO2e per capita (2000)",
           "Metric tons of CO2e per capita (2005)",
           "Metric tons of CO2e per capita (2010)",
           "Metric tons of CO2e per capita (2013)",
           "Metric tons of CO2e per capita (2018)"]
    df = pd.read_csv(r"C:\Users\Zidan Ahmed\Videos\archive (87)\production_based_co2_emissions.csv", usecols=columns)
    df.set_index("Country", inplace=True)
    selected_country = "Zimbabwe"
    selected_country_data = df.loc[selected_country]
    selected_country_data.plot(kind="bar")
    plt.xlabel("Year")
    plt.ylabel("Metric tons of CO2e per capita")
    plt.title(f"CO2 Emissions per Capita for {selected_country} Over the Years")
    plt.show()
    m.destroy()



def map1990():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (1990)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()
def map1995():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (1995)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()

def map2000():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (2000)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()

def map2005():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (2005)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()

def map2010():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (2010)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()

def map2013():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (2013)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()

def map2018():
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    data_file = "C:\\Users\\Zidan Ahmed\\Videos\\archive (87)\\production_based_co2_emissions.csv"
    data = pd.read_csv(data_file)
    merged_data = world.merge(data, left_on='name', right_on='Country')
    column_to_visualize = 'Metric tons of CO2e per capita (2018)'
    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)

    merged_data.plot(column=column_to_visualize, ax=ax, legend=True, cax=cax, legend_kwds={'label': f'{column_to_visualize} per Country'})
    ax.set_title(f'World Map - {column_to_visualize}')
    plt.show()
    m.destroy()
def a():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name A')
    ttk.tkinter.Button(w8,text="Afghanistan",command=matplot).pack() 
    ttk.tkinter.Button(w8,text="Albania",command=matplot2).pack()
    ttk.tkinter.Button(w8,text="Algeria",command=matplot3).pack()
    ttk.tkinter.Button(w8,text="Angola",command=matplot4).pack()
    ttk.tkinter.Button(w8,text="Antigua and Barbuda",command=matplot5).pack() 
    ttk.tkinter.Button(w8,text="Argentina",command=matplot6).pack() 
    ttk.tkinter.Button(w8,text="Armenia",command=matplot7).pack()
    ttk.tkinter.Button(w8,text="Australia",command=matplot8).pack()
    ttk.tkinter.Button(w8,text="Austria",command=matplot9).pack()
    ttk.tkinter.Button(w8,text="Azerbaijan",command=matplot10).pack()
    
def b1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name A')
    ttk.tkinter.Button(w8,text="Bahamas",command=matplot11).pack() 
    ttk.tkinter.Button(w8,text="Bahrain",command=matplot12).pack()
    ttk.tkinter.Button(w8,text="Bangladesh",command=matplot13).pack()
    ttk.tkinter.Button(w8,text="Barbados",command=matplot14).pack()
    ttk.tkinter.Button(w8,text="Belarus",command=matplot15).pack()
    ttk.tkinter.Button(w8,text="Belgium",command=matplot16).pack() 
    ttk.tkinter.Button(w8,text="Belize",command=matplot17).pack() 
    ttk.tkinter.Button(w8,text="Benin",command=matplot18).pack()
    ttk.tkinter.Button(w8,text="Bhutan",command=matplot19).pack()
    ttk.tkinter.Button(w8,text="Bolivia",command=matplot20).pack()
    ttk.tkinter.Button(w8,text="Bosnia and Herzegovina",command=matplot21).pack()
    ttk.tkinter.Button(w8,text="Botswana",command=matplot22).pack()
    ttk.tkinter.Button(w8,text="Brazil",command=matplot23).pack()
    ttk.tkinter.Button(w8,text="Brunei",command=matplot24).pack()
    ttk.tkinter.Button(w8,text="Bulgaria",command=matplot25).pack()
    ttk.tkinter.Button(w8,text="Burkina Faso",command=matplot26).pack()
    ttk.tkinter.Button(w8,text="Burundi",command=matplot27).pack()

    
def c1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name C')
    ttk.tkinter.Button(w8,text="Cambodia",command=matplot28).pack() 
    ttk.tkinter.Button(w8,text="Cameroon",command=matplot29).pack()
    ttk.tkinter.Button(w8,text="Canada",command=matplot30).pack()
    ttk.tkinter.Button(w8,text="Cape Verde",command=matplot31).pack()
    ttk.tkinter.Button(w8,text="Central African Republic",command=matplot32).pack() 
    ttk.tkinter.Button(w8,text="Chad",command=matplot33).pack() 
    ttk.tkinter.Button(w8,text="Chile",command=matplot34).pack()
    ttk.tkinter.Button(w8,text="China",command=matplot35).pack()
    ttk.tkinter.Button(w8,text="Colombia",command=matplot36).pack()
    ttk.tkinter.Button(w8,text="Comoros",command=matplot37).pack()
    ttk.tkinter.Button(w8,text="Costa Rica",command=matplot38).pack()
    ttk.tkinter.Button(w8,text="Croatia",command=matplot39).pack()
    ttk.tkinter.Button(w8,text="Cuba",command=matplot40).pack()
    ttk.tkinter.Button(w8,text="Cyprus",command=matplot41).pack()
    ttk.tkinter.Button(w8,text="Czech Republic",command=matplot42).pack()
      
        
def d1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name D')
    ttk.tkinter.Button(w8,text="Denmark",command=matplot43).pack() 
    ttk.tkinter.Button(w8,text="Djibouti",command=matplot44).pack()
    ttk.tkinter.Button(w8,text="Dominica",command=matplot45).pack()
    ttk.tkinter.Button(w8,text="Dominican Republic",command=matplot46).pack() 
    
    

    
    
def e1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name E')
    ttk.tkinter.Button(w8,text="Ecuador",command=matplot47).pack() 
    ttk.tkinter.Button(w8,text="Egypt",command=matplot48).pack()
    ttk.tkinter.Button(w8,text="El Salvador",command=matplot49).pack()
    ttk.tkinter.Button(w8,text="Equatorial Guinea",command=matplot50).pack() 
    ttk.tkinter.Button(w8,text="Eritrea",command=matplot51).pack() 
    ttk.tkinter.Button(w8,text="Estonia",command=matplot52).pack()
    ttk.tkinter.Button(w8,text="Eswatini",command=matplot53).pack()
    ttk.tkinter.Button(w8,text="Ethiopia",command=matplot54).pack() 
    
    
    
    
def f1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name F')
    ttk.tkinter.Button(w8,text="Fiji",command=matplot55).pack() 
    ttk.tkinter.Button(w8,text="Finland",command=matplot56).pack()
    ttk.tkinter.Button(w8,text="France",command=matplot57).pack()
    
    
    
    
def g1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name G')
    ttk.tkinter.Button(w8,text="Gabon",command=matplot58).pack() 
    ttk.tkinter.Button(w8,text="Gambia",command=matplot59).pack()
    ttk.tkinter.Button(w8,text="Georgia",command=matplot60).pack()
    ttk.tkinter.Button(w8,text="Germany",command=matplot61).pack() 
    ttk.tkinter.Button(w8,text="Ghana",command=matplot62).pack() 
    ttk.tkinter.Button(w8,text="Greece",command=matplot63).pack()
    ttk.tkinter.Button(w8,text="Grenada",command=matplot64).pack()
    ttk.tkinter.Button(w8,text="Guatemala",command=matplot65).pack()
    ttk.tkinter.Button(w8,text="Guinea",command=matplot66).pack() 
    ttk.tkinter.Button(w8,text="Guinea-Bissau",command=matplot67).pack()
    ttk.tkinter.Button(w8,text="Guyana",command=matplot68).pack()

    
def h1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name H')
    ttk.tkinter.Button(w8,text="Haiti",command=matplot69).pack() 
    ttk.tkinter.Button(w8,text="Honduras",command=matplot70).pack()
    ttk.tkinter.Button(w8,text="Hungary",command=matplot71).pack()
def i1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name I')
    ttk.tkinter.Button(w8,text="Iceland",command=matplot72).pack() 
    ttk.tkinter.Button(w8,text="India",command=matplot73).pack()
    ttk.tkinter.Button(w8,text="Indonesia",command=matplot74).pack()
    ttk.tkinter.Button(w8,text="Iran",command=matplot75).pack() 
    ttk.tkinter.Button(w8,text="Iraq",command=matplot76).pack()
    ttk.tkinter.Button(w8,text="Ireland",command=matplot77).pack()
    ttk.tkinter.Button(w8,text="Israel",command=matplot78).pack() 
    ttk.tkinter.Button(w8,text="Italy",command=matplot79).pack()
    ttk.tkinter.Button(w8,text="Ivory Coast",command=matplot80).pack()
def j1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name J')
    ttk.tkinter.Button(w8,text="Jamaica",command=matplot81).pack() 
    ttk.tkinter.Button(w8,text="Japan",command=matplot82).pack()
    ttk.tkinter.Button(w8,text="Jordan",command=matplot83).pack()

def k1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name K')
    ttk.tkinter.Button(w8,text="Kazakhstan",command=matplot84).pack() 
    ttk.tkinter.Button(w8,text="Kenya",command=matplot85).pack()
    ttk.tkinter.Button(w8,text="Kiribati",command=matplot86).pack()
    ttk.tkinter.Button(w8,text="Kuwait",command=matplot87).pack() 
    ttk.tkinter.Button(w8,text="Kyrgyzstan",command=matplot88).pack() 
    
def l1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name L')
    ttk.tkinter.Button(w8,text="Laos",command=matplot89).pack() 
    ttk.tkinter.Button(w8,text="Latvia",command=matplot90).pack()
    ttk.tkinter.Button(w8,text="Lebanon",command=matplot91).pack()
    ttk.tkinter.Button(w8,text="Lesotho",command=matplot92).pack() 
    ttk.tkinter.Button(w8,text="Liberia",command=matplot93).pack()
    ttk.tkinter.Button(w8,text="Libya",command=matplot94).pack()
    ttk.tkinter.Button(w8,text="Lithuania",command=matplot95).pack() 
    ttk.tkinter.Button(w8,text="Luxembourg",command=matplot96).pack()
def m1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name M')
    ttk.tkinter.Button(w8,text="Madagascar",command=matplot97).pack() 
    ttk.tkinter.Button(w8,text="Malawi",command=matplot98).pack()
    ttk.tkinter.Button(w8,text="Malaysia",command=matplot99).pack()
    ttk.tkinter.Button(w8,text="Maldives",command=matplot100).pack() 
    ttk.tkinter.Button(w8,text="Mali",command=matplot101).pack() 
    ttk.tkinter.Button(w8,text="Malta",command=matplot102).pack()
    ttk.tkinter.Button(w8,text="Mauritania",command=matplot103).pack()
    ttk.tkinter.Button(w8,text="Mauritius",command=matplot104).pack()
    ttk.tkinter.Button(w8,text="Mexico",command=matplot105).pack() 
    ttk.tkinter.Button(w8,text="Moldova",command=matplot106).pack()
    ttk.tkinter.Button(w8,text="Mongolia",command=matplot107).pack()
    ttk.tkinter.Button(w8,text="Montenegro",command=matplot108).pack() 
    ttk.tkinter.Button(w8,text="Morocco",command=matplot109).pack()
    ttk.tkinter.Button(w8,text="Mozambique",command=matplot110).pack()
    ttk.tkinter.Button(w8,text="Myanmar",command=matplot111).pack()
def n1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name N')
    ttk.tkinter.Button(w8,text="Namibia",command=matplot112).pack() 
    ttk.tkinter.Button(w8,text="Nauru",command=matplot113).pack()
    ttk.tkinter.Button(w8,text="Nepal",command=matplot114).pack()
    ttk.tkinter.Button(w8,text="Netherlands",command=matplot115).pack() 
    ttk.tkinter.Button(w8,text="New Zealand",command=matplot116).pack() 
    ttk.tkinter.Button(w8,text="Nicaragua",command=matplot117).pack()
    ttk.tkinter.Button(w8,text="Niger",command=matplot118).pack()
    ttk.tkinter.Button(w8,text="Nigeria",command=matplot119).pack()
    ttk.tkinter.Button(w8,text="North Korea",command=matplot120).pack() 
    ttk.tkinter.Button(w8,text="Norway",command=matplot121).pack()
def o1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name O')
    ttk.tkinter.Button(w8,text="Oman",command=matplot122).pack() 
    
def p1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name P')
    ttk.tkinter.Button(w8,text="Pakistan",command=matplot123).pack() 
    ttk.tkinter.Button(w8,text="Palau",command=matplot124).pack()
    ttk.tkinter.Button(w8,text="Panama",command=matplot125).pack()
    ttk.tkinter.Button(w8,text="Papua New Guinea",command=matplot126).pack() 
    ttk.tkinter.Button(w8,text="Paraguay",command=matplot127).pack() 
    ttk.tkinter.Button(w8,text="Peru",command=matplot128).pack()
    ttk.tkinter.Button(w8,text="Philippines",command=matplot129).pack() 
    ttk.tkinter.Button(w8,text="Poland",command=matplot130).pack() 
    ttk.tkinter.Button(w8,text="Portugal",command=matplo131).pack()
def q1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name Q')
    ttk.tkinter.Button(w8,text="Qatar",command=matplot132).pack() 
def r1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name R')
    ttk.tkinter.Button(w8,text="Republic of the Congo",command=matplot133).pack() 
    ttk.tkinter.Button(w8,text="Romania",command=matplot134).pack()
    ttk.tkinter.Button(w8,text="Russia",command=matplot135).pack()
    ttk.tkinter.Button(w8,text="Rwanda",command=matplot136).pack() 
def s1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name S')
    ttk.tkinter.Button(w8,text="Saint Kitts and Nevis",command=matplot137).pack() 
    ttk.tkinter.Button(w8,text="Saint Lucia",command=matplot138).pack()
    ttk.tkinter.Button(w8,text="Saint Vincent and the Grenadines",command=matplot139).pack()
    ttk.tkinter.Button(w8,text="Samoa",command=matplot140).pack() 
    ttk.tkinter.Button(w8,text="São Tomé and Príncipe",command=matplot141).pack() 
    ttk.tkinter.Button(w8,text="Saudi Arabia",command=matplot142).pack() 
    ttk.tkinter.Button(w8,text="Senegal",command=matplot143).pack() 
    ttk.tkinter.Button(w8,text="Serbia",command=matplot144).pack()
    ttk.tkinter.Button(w8,text="Seychelles",command=matplot145).pack()
    ttk.tkinter.Button(w8,text="Sierra Leone",command=matplot146).pack() 
    ttk.tkinter.Button(w8,text="Singapore",command=matplot147).pack() 
    ttk.tkinter.Button(w8,text="Slovakia",command=matplot148).pack()
    ttk.tkinter.Button(w8,text="Slovenia",command=matplot149).pack() 
    ttk.tkinter.Button(w8,text="Solomon Islands",command=matplot150).pack()
    ttk.tkinter.Button(w8,text="South Africa",command=matplot151).pack()
    ttk.tkinter.Button(w8,text="South Korea",command=matplot152).pack() 
    ttk.tkinter.Button(w8,text="Spain",command=matplot153).pack()
    ttk.tkinter.Button(w8,text="Sri Lanka",command=matplot154).pack()
    ttk.tkinter.Button(w8,text="Sudan",command=matplot155).pack() 
    ttk.tkinter.Button(w8,text="Suriname",command=matplot156).pack()
    ttk.tkinter.Button(w8,text="Sweden",command=matplot157).pack()
    ttk.tkinter.Button(w8,text="Switzerland",command=matplot158).pack() 
    ttk.tkinter.Button(w8,text="Syria",command=matplot159).pack()
def t1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name T')
    ttk.tkinter.Button(w8,text="Tajikistan",command=matplot160).pack() 
    ttk.tkinter.Button(w8,text="Tanzania",command=matplot161).pack()
    ttk.tkinter.Button(w8,text="Thailand",command=matplot162).pack()
    ttk.tkinter.Button(w8,text="Togo",command=matplot163).pack() 
    ttk.tkinter.Button(w8,text="Tonga",command=matplot164).pack() 
    ttk.tkinter.Button(w8,text="Trinidad and Tobago",command=matplot165).pack() 
    ttk.tkinter.Button(w8,text="Tunisia",command=matplot166).pack() 
    ttk.tkinter.Button(w8,text="Turkey",command=matplot167).pack()
    ttk.tkinter.Button(w8,text="Turkmenistan",command=matplot168).pack()
def u1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name U')
    ttk.tkinter.Button(w8,text="Uganda",command=matplot169).pack() 
    ttk.tkinter.Button(w8,text="Ukraine",command=matplot170).pack()
    ttk.tkinter.Button(w8,text="United Arab Emirates",command=matplot171).pack()
    ttk.tkinter.Button(w8,text="United Kingdom",command=matplot172).pack() 
    ttk.tkinter.Button(w8,text="United States",command=matplot173).pack() 
    ttk.tkinter.Button(w8,text="Uruguay",command=matplot174).pack() 
    ttk.tkinter.Button(w8,text="Uzbekistan",command=matplot175).pack()
    
def v1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name V')
    ttk.tkinter.Button(w8,text="Vanuatu",command=matplot176).pack() 
    ttk.tkinter.Button(w8,text="Venezuela",command=matplot177).pack()
    ttk.tkinter.Button(w8,text="Vietnam",command=matplot178).pack()
def y1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name Y')
    ttk.tkinter.Button(w8,text="Yemen",command=matplot179).pack()
def z1():
    w8=Toplevel(m)
    w8.geometry("1200x900")
    w8.title('Countries with Name Z')
    ttk.tkinter.Button(w8,text="Zambia",command=matplot180).pack() 
    ttk.tkinter.Button(w8,text="Zimbabwe",command=matplot181).pack()

m.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Zidan Ahmed\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Zidan Ahmed\AppData\Local\Temp\ipykernel_3064\2310163508.py", line 4620, in p1
#     ttk.tkinter.Button(w8,text="Portugal",command=matplo131).pack()
# NameError: name 'matplo131' is not defined
